# %%
arr = []
arr2 = []

MyFile=open('filelist.txt','r')
total_count=0

for x in MyFile.read().split(';'):
    for y in x.split():
        if(total_count%2==0):
            narr = [y]
            arr = arr + narr
        else:
            narr2 = [y]
            arr2 = arr2 + narr2
            
        total_count = total_count+1;
        


a=[]
a1=[]
count_all_words=0 #count all words in the original cls
ln = len(arr) 
count={}
for x in range(0,ln):
    if(arr2[x]=='sp'):
        MyFile=open(arr[x],'r')
        for y in MyFile.read().split():
            count_all_words+=1
            if y in count:
                count[y]+=1
            else:
                count[y]=1
for word,times in count.items():
    a.append(word)
    a1.append(times) 

b=[]
b1=[]
count_all_words2=0
count={}
for x in range(0,ln):
    if(arr2[x]=='b'):
        MyFile=open(arr[x],'r')
        for y in MyFile.read().split():
            count_all_words2+=1
            if y in count:
                count[y]+=1
            else:
                count[y]=1
for word,times in count.items():
    b.append(word)
    b1.append(times)
     
c=[]
c1=[]
count_all_words3=0
ln = len(arr) 
count={}
for x in range(0,ln):
    if(arr2[x]=='e'):
        MyFile=open(arr[x],'r')
        for y in MyFile.read().split():
            count_all_words3+=1
            if y in count:
                count[y]+=1
            else:
                count[y]=1
for word,times in count.items():
    c.append(word)
    c1.append(times)

d=[]
d1=[]
count_all_words4=0
ln = len(arr) 
count={}
for x in range(0,ln):
    if(arr2[x]=='p'):
        MyFile=open(arr[x],'r')
        for y in MyFile.read().split():
            count_all_words4+=1
            if y in count:
                count[y]+=1
            else:
                count[y]=1
for word,times in count.items():
    d.append(word)
    d1.append(times)
    
e=[]
e1=[]
count_all_words5=0
ln = len(arr) 
count={}
for x in range(0,ln):
    if(arr2[x]=='t'):
        MyFile=open(arr[x],'r')
        for y in MyFile.read().split():
            count_all_words5+=1
            if y in count:
                count[y]+=1
            else:
                count[y]=1
for word,times in count.items():
    e.append(word)
    e1.append(times)

lna1=len(a1) 
lnb1=len(b1)
lnc1=len(c1)
lnd1=len(d1)
lne1=len(e1)

p_i_sp=[]
for i in range(0,lna1):
    p_i_sp.append(float(a1[i]+1)/(count_all_words+(lna1+lnb1+lnc1+lnd1+lne1)))
    
with open('Conditnal_probabilities_sp.txt','w') as f:
      for i in range(0,lna1):
            f.write('%s %.20f;\n' %(a[i],p_i_sp[i]))
            print ("%s %.20f", (a[i],p_i_sp[i]) )
    
    
p_i_b=[]
for i in range(0,lnb1):
    p_i_b.append(float(b1[i]+1)/(count_all_words2+(lna1+lnb1+lnc1+lnd1+lne1)))

with open('Conditnal_probabilities_b.txt','w') as f:
      for i in range(0,lnb1):
            f.write('%s %.20f;\n' %(b[i],p_i_b[i]))
            
p_i_e=[]
for i in range(0,lnc1):
    p_i_e.append(float(c1[i]+1)/(count_all_words3+(lna1+lnb1+lnc1+lnd1+lne1)))

with open('Conditnal_probabilities_e.txt','w') as f:
      for i in range(0,lnc1):
            f.write('%s %.20f;\n' %(c[i],p_i_e[i]))
    
p_i_p=[]
for i in range(0,lnd1):
    p_i_p.append(float(d1[i]+1)/(count_all_words4+(lna1+lnb1+lnc1+lnd1+lne1)))

with open('Conditnal_probabilities_p.txt','w') as f:
      for i in range(0,lnd1):
            f.write('%s %.20f;\n' %(d[i],p_i_p[i]))
            
p_i_t=[]
for i in range(0,lne1):
    p_i_t.append(float(e1[i]+1)/(count_all_words5+(lna1+lnb1+lnc1+lnd1+lne1)))

with open('Conditnal_probabilities_t.txt','w') as f:
      for i in range(0,lne1):
            f.write('%s %.20f;\n' %(e[i],p_i_t[i]))
       
    
print (p_i_sp)
print (p_i_b)
print (p_i_e)
print (p_i_p)
print (p_i_t)
# Out:
# %s %.20f ('hundr', 0.0003386386725364037)
# %s %.20f ('pair', 0.0003386386725364037)
# %s %.20f ('zac', 0.0003386386725364037)
# %s %.20f ('17th', 0.0003386386725364037)
# %s %.20f ('sakat', 0.0003386386725364037)
# %s %.20f ('joel', 0.0003386386725364037)
# %s %.20f ('sit', 0.0003386386725364037)
# %s %.20f ('cautiou', 0.0003386386725364037)
# %s %.20f ('shahriar', 0.0003386386725364037)
# %s %.20f ('march', 0.0003386386725364037)
# %s %.20f ('practic', 0.0003386386725364037)
# %s %.20f ('jonathan', 0.0003386386725364037)
# %s %.20f ('allround', 0.0003386386725364037)
# %s %.20f ('want', 0.0003386386725364037)
# %s %.20f ('total', 0.0003386386725364037)
# %s %.20f ('push', 0.0003386386725364037)
# %s %.20f ('thoughout', 0.0003386386725364037)
# %s %.20f ('around', 0.0003386386725364037)
# %s %.20f ('withstand', 0.0003386386725364037)
# %s %.20f ('anthoni', 0.0005079580088046055)
# %s %.20f ('unit', 0.0018625126989502202)
# %s %.20f ('coupl', 0.0003386386725364037)
# ...
