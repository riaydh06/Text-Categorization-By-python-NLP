# %%
import re
import nltk
from nltk.tokenize import word_tokenize,sent_tokenize
from nltk.corpus import stopwords
from nltk.stem.lancaster import LancasterStemmer
from nltk.stem import PorterStemmer
from collections import Counter
from collections import defaultdict
import math
import os
import os.path
st=PorterStemmer()
path = 'C:\\Users\\ret\\politics_2' 
files = os.listdir(path)
os.chdir(path)

with open('317.txt') as f:
    read_data = word_tokenize(f.read())
    
read_data=filter(str.isalnum,read_data)    
stop_words=set(stopwords.words("english"))
#filtered_sentence=[]word_list
filtered_sentence=[w for w in read_data if not w in stop_words]
path = 'C:\\Users\\ret'
os.chdir(path)

filtered_sentence=[item.lower() for item in filtered_sentence]
filtered_sentence=[x for x in filtered_sentence if not x.isdigit()]
    
for words in filtered_sentence:
    if ( len(words)==1 ) :
        filtered_sentence.remove(words)
for x in filtered_sentence:
    if ( len(x)==2 ) :
        filtered_sentence.remove(x)
        
filtered_sentence=[st.stem(f) for f in filtered_sentence] 



e=[]
f=[]
count={}
for w in filtered_sentence:
    if w in count:
        count[w]+=1
    else:
        count[w]=1

for word,times in count.items():
    e.append(word)
    f.append(times)

#h=e
#i=f

g=len(f)

#print ("sports")
arr = []
arr2 = []
MyFile=open('Conditnal_probabilities_sport_1.txt','r')
total_count=0

for x in MyFile.read().split(';'):
    for y in x.split():
        if(total_count%2==0):
            narr = [y]
            arr = arr + narr
        else:
            narr2 = [y]
            arr2 = arr2 + narr2
            
        total_count = total_count+1;
        
#print (arr)
c_sp=0
#for sports:
p_newins_sp=0.0
for i in range(0,g):
    for j in range(0,len(arr)):
        if(e[i]==arr[j]):
                p_newins_sp+= (20.0/100.0)*pow(float(arr2[j]),f[i])
                c_sp+=1
                #print ('%s %f', (e[i],p_newins_sp))


#print ("business")
arr = []
arr2 = []
MyFile=open('Conditnal_probabilities_bussiness_1.txt','r')
total_count=0

for x in MyFile.read().split(';'):
    for y in x.split():
        if(total_count%2==0):
            narr = [y]
            arr = arr + narr
        else:
            narr2 = [y]
            arr2 = arr2 + narr2
            
        total_count = total_count+1;
#for business
c_b=0
p_newins_b=0.0
for i in range(0,g):
    for j in range(0,len(arr)):
            if(e[i]==arr[j]):
                p_newins_b+= (20.0/100.0)* pow(float(arr2[j]),f[i])
                c_b+=1
                #print ( p_newins_b)

#print (c_b)
#print ("Entertainment")
arr = []
arr2 = []
MyFile=open('Conditnal_probabilities_entertainment_1.txt','r')
total_count=0

for x in MyFile.read().split(';'):
    for y in x.split():
        if(total_count%2==0):
            narr = [y]
            arr = arr + narr
        else:
            narr2 = [y]
            arr2 = arr2 + narr2
            
        total_count = total_count+1;

#for entertainment
c_e=0
p_newins_e=0.0
for i in range(0,g):
    for j in range(0,len(arr)):
          if(e[i]==arr[j]):
                p_newins_e+= (20.0/100.0)* pow(float(arr2[j]),f[i])
                c_e+=1
                #print ( p_newins_e)
#print (c_e)                
#print ("politics")
arr = []
arr2 = []
MyFile=open('Conditnal_probabilities_politics_1.txt','r')
total_count=0

for x in MyFile.read().split(';'):
    for y in x.split():
        if(total_count%2==0):
            narr = [y]
            arr = arr + narr
        else:
            narr2 = [y]
            arr2 = arr2 + narr2
            
        total_count = total_count+1;
        
#print (arr)
#for politics:
c_p=0
p_newins_p=0.0
for i in range(0,g):
    for j in range(0,len(arr)):
        if(e[i]==arr[j]):
                p_newins_p+= (20.0/100.0)*pow(float(arr2[j]),f[i])
                c_p+=1
                #print ( p_newins_p)
#print (c_p)
#print ("technology")
arr = []
arr2 = []
MyFile=open('Conditnal_probabilities_technology_1.txt','r')
total_count=0

for x in MyFile.read().split(';'):
    for y in x.split():
        if(total_count%2==0):
            narr = [y]
            arr = arr + narr
        else:
            narr2 = [y]
            arr2 = arr2 + narr2
            
        total_count = total_count+1;
        
#print (arr)
#for technology
c_t=0
p_newins_t=0.0
for i in range(0,g):
    for j in range(0,len(arr)):
        if(e[i]==arr[j]):
                p_newins_t+= (17.0/100.0)*pow(float(arr2[j]),f[i])
                c_t+=1
                #print ( p_newins_t)
                
#print (c_t)
print ('sp=%s b=%s e=%s p=%s t=%s' %(p_newins_sp,p_newins_b,p_newins_e,p_newins_p,p_newins_t))
# Out:
# sp=0.00487461925510785 b=0.0063695843895331845 e=0.003571696264903376 p=0.008752182104476347 t=0.00740593762350037

# %%
path = 'C:\\Users\\ret\\sport_2' 
files = os.listdir(path)
os.chdir(path)
files_txt = [i for i in files if i.endswith('.txt')]
a=[]
b= [[]]
for x in range(0,len(files_txt)):
        MyFile=open(files_txt[x],'r')
        for y in MyFile.read().split():
             a+=[y]
