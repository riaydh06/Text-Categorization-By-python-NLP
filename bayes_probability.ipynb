# %%
import re
import nltk
from nltk.tokenize import word_tokenize,sent_tokenize
from nltk.corpus import stopwords
from nltk.stem.lancaster import LancasterStemmer
from nltk.stem import PorterStemmer
from collections import Counter
from collections import defaultdict
import math


st=PorterStemmer()

with open('001.txt') as f:
    read_data = word_tokenize(f.read())
    
stop_words=set(stopwords.words("english"))
#filtered_sentence=[]word_list
filtered_sentence=[w for w in read_data if not w in stop_words]
    
filtered_sentence=[item.lower() for item in filtered_sentence]
filtered_sentence=[x for x in filtered_sentence if not x.isdigit()]
    
    
for words in filtered_sentence:
    if ( len(words)==1 ) :
        filtered_sentence.remove(words)

filtered_sentence=[st.stem(f) for f in filtered_sentence]

#MyFile=open('file_corpus_new instance.txt','r')
e=[]
f=[]
count={}
for w in open('file_corpus_new instance001.txt').read().split():
    if w in count:
        count[w]+=1
    else:
        count[w]=1

for word,times in count.items():
    e.append(word)
    f.append(times)
g=len(f)

arr = []
arr2 = []
MyFile=open('Conditnal_probabilities_sp.txt','r')
total_count=0

for x in MyFile.read().split(';'):
    for y in x.split():
        if(total_count%2==0):
            narr = [y]
            arr = arr + narr
        else:
            narr2 = [y]
            arr2 = arr2 + narr2
            
        total_count = total_count+1;
        
#print (arr)
#for sports:
p_newins_sp=0.0
for i in range(0,g):
    for j in range(0,len(arr)):
        if(e[i]==arr[j]):
                p_newins_sp+= (7.0/20.0)*pow(float(arr2[j]),f[i])


arr = []
arr2 = []
MyFile=open('Conditnal_probabilities_e.txt','r')
total_count=0

for x in MyFile.read().split(';'):
    for y in x.split():
        if(total_count%2==0):
            narr = [y]
            arr = arr + narr
        else:
            narr2 = [y]
            arr2 = arr2 + narr2
            
        total_count = total_count+1;
#for environment
p_newins_e=0.0
for i in range(0,g):
    for j in range(0,len(arr)):
            if(e[i]==arr[j]):
                p_newins_e+= (7.0/20.0)* pow(float(arr2[j]),f[i])
                
arr = []
arr2 = []
MyFile=open('Conditnal_probabilities_b.txt','r')
total_count=0

for x in MyFile.read().split(';'):
    for y in x.split():
        if(total_count%2==0):
            narr = [y]
            arr = arr + narr
        else:
            narr2 = [y]
            arr2 = arr2 + narr2
            
        total_count = total_count+1;

#for business
p_newins_b=0.0
for i in range(0,g):
    for j in range(0,len(arr)):
          if(e[i]==arr[j]):
                p_newins_b+= (6.0/20.0)* pow(float(arr2[j]),f[i])
                
print ('%s %s %s' %(p_newins_sp,p_newins_e,p_newins_b))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-d15334edaa1d> in <module>()
#      12 st=PorterStemmer()
#      13
# ---> 14 with open('001.txt') as f:
#      15     read_data = word_tokenize(f.read())
#      16
#
# FileNotFoundError: [Errno 2] No such file or directory: '001.txt'
