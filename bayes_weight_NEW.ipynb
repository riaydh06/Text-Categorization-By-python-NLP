# %%
import re
import nltk
from nltk.tokenize import word_tokenize,sent_tokenize
from nltk.corpus import stopwords
from nltk.stem.lancaster import LancasterStemmer
from nltk.stem import PorterStemmer
from collections import Counter
from collections import defaultdict
import math

import os
import os.path
st=PorterStemmer()
path = 'C:\\Users\\ret\\technology_1' 
files = os.listdir(path)
os.chdir(path)
with open('020.txt') as f:
    read_data = word_tokenize(f.read())
    
read_data=filter(str.isalnum,read_data)    
stop_words=set(stopwords.words("english"))
#filtered_sentence=[]word_list
filtered_sentence=[w for w in read_data if not w in stop_words]
path = 'C:\\Users\\ret'
os.chdir(path)

filtered_sentence=[item.lower() for item in filtered_sentence]
filtered_sentence=[x for x in filtered_sentence if not x.isdigit()]
    
for words in filtered_sentence:
    if ( len(words)==1 ) :
        filtered_sentence.remove(words)
for x in filtered_sentence:
    if ( len(x)==2 ) :
        filtered_sentence.remove(x)
        
filtered_sentence=[st.stem(f) for f in filtered_sentence] 



e=[]
f=[]
count={}
for w in filtered_sentence:
    if w in count:
        count[w]+=1
    else:
        count[w]=1

for word,times in count.items():
    e.append(word)
    f.append(times)

g=len(f)

#print ("sports")
arr = []
arr2 = []
MyFile=open('Conditnal_probabilities_sport_2.txt','r')
total_count=0

for x in MyFile.read().split(';'):
    for y in x.split():
        if(total_count%2==0):
            narr = [y]
            arr = arr + narr
        else:
            narr2 = [y]
            arr2 = arr2 + narr2
            
        total_count = total_count+1;
                
#weight_matrix_sp
arr3 = []
arr4 = []

MyFile=open('weightmatrix_sp_2.txt','r')
total_count=0

for x in MyFile.read().split(';'):
    for y in x.split():
        if(total_count%2==0):
            narr = [y]
            arr3 = arr3 + narr
        else:
            narr2 = [y]
            arr4 = arr4 + narr2
            
        total_count = total_count+1;
        
        
#print (arr3)
#print (arr4)
c_sp=0
#for sports:
p_newins_sp=0.0
for i in range(0,g):
    for j in range(0,len(arr)):
        if(e[i]==arr[j]):
                p_newins_sp+= (10.0/50.0)*pow(float(arr2[j]),f[i])
                c_sp+=1
                print ('%s %f', (e[i],p_newins_sp))               

print ("  \n\nsports\n")
print ('sp_bayes=%s' %(p_newins_sp))
wc_sp=0
for i in range(0,g):
    for j in range(0,len(arr3)):
        if(e[i]==arr3[j]):
                print ('%s %s' %(e[i],arr3[j]))
                print (arr4[j])
                print(f[i])
                if(f[i]>4):
                    p_newins_sp+= float(arr4[j])
                    print(e[i])
                else:
                    for i in range(0,(f[i])):
                        p_newins_sp+= float(arr4[j])
                print ('%s %f', (e[i],p_newins_sp))
print ('\n%s %f', (e[i],p_newins_sp))
#print ('c_sp: %d %d ', (c_sp,wc_sp))



arr = []
arr2 = []
MyFile=open('Conditnal_probabilities_bussiness_2.txt','r')
total_count=0

for x in MyFile.read().split(';'):
    for y in x.split():
        if(total_count%2==0):
            narr = [y]
            arr = arr + narr
        else:
            narr2 = [y]
            arr2 = arr2 + narr2
            
        total_count = total_count+1;
        
#weight_matrix_b
arr3 = []
arr4 = []

MyFile=open('weightmatrix_b_2.txt','r')
total_count=0

for x in MyFile.read().split(';'):
    for y in x.split():
        if(total_count%2==0):
            narr = [y]
            arr3 = arr3 + narr
        else:
            narr2 = [y]
            arr4 = arr4 + narr2
            
        total_count = total_count+1;
        


#print (arr3)
#print (arr4)
#for business
c_b=0
p_newins_b=0.0
for i in range(0,g):
    for j in range(0,len(arr)):
            if(e[i]==arr[j]):
                p_newins_b+= (10.0/50.0)* pow(float(arr2[j]),f[i])
                c_b+=1
                #print ( p_newins_b)

#print ("  business") 
print ('b_bayes=%s' %(p_newins_b))
wc_b=0
for i in range(0,g):
    for j in range(0,len(arr3)):
        if(e[i]==arr3[j]):
                wc_b+=1
                #print ('%s %s' %(e[i],arr3[j]))
                #print (arr4[j])
                if(f[i]>4):
                    p_newins_b+= float(arr4[j])
                else:
                    for i in range(0,(f[i])):
                        p_newins_b+= float(arr4[j])
                
#print ('c_b: %d %d ', (c_b,wc_b))

arr = []
arr2 = []
MyFile=open('Conditnal_probabilities_entertainment_2.txt','r')
total_count=0

for x in MyFile.read().split(';'):
    for y in x.split():
        if(total_count%2==0):
            narr = [y]
            arr = arr + narr
        else:
            narr2 = [y]
            arr2 = arr2 + narr2
            
        total_count = total_count+1;
        
#weight_matrix_e
arr3 = []
arr4 = []

MyFile=open('weightmatrix_e_2.txt','r')
total_count=0

for x in MyFile.read().split(';'):
    for y in x.split():
        if(total_count%2==0):
            narr = [y]
            arr3 = arr3 + narr
        else:
            narr2 = [y]
            arr4 = arr4 + narr2
            
        total_count = total_count+1;

#for entertainment
c_e=0
p_newins_e=0.0
for i in range(0,g):
    for j in range(0,len(arr)):
          if(e[i]==arr[j]):
                p_newins_e+= (10.0/50.0)* pow(float(arr2[j]),f[i])
                c_e+=1
#print ("  Entertainment")
print ('e_bayes=%s' %(p_newins_e))
for i in range(0,g):
    for j in range(0,len(arr3)):
        if(e[i]==arr3[j]):
                #print (arr4[j])
                #print ('%s %s' %(e[i],arr3[j]))
                if(f[i]>4):
                    p_newins_e+=float(arr4[j])
                else:
                    for i in range(0,(f[i])):
                        p_newins_e+=float(arr4[j]) 
                
arr = []
arr2 = []
MyFile=open('Conditnal_probabilities_politics_2.txt','r')
total_count=0

for x in MyFile.read().split(';'):
    for y in x.split():
        if(total_count%2==0):
            narr = [y]
            arr = arr + narr
        else:
            narr2 = [y]
            arr2 = arr2 + narr2
            
        total_count = total_count+1;
        
#weight_matrix_p
arr3 = []
arr4 = []

MyFile=open('weightmatrix_p_2.txt','r')
total_count=0

for x in MyFile.read().split(';'):
    for y in x.split():
        if(total_count%2==0):
            narr = [y]
            arr3 = arr3 + narr
        else:
            narr2 = [y]
            arr4 = arr4 + narr2
            
        total_count = total_count+1;

#for politics
c_p=0
p_newins_p=0.0
for i in range(0,g):
    for j in range(0,len(arr)):
        if(e[i]==arr[j]):
                p_newins_p+= (10.0/50.0)*pow(float(arr2[j]),f[i])
                c_p+=1
                
#print ("  politics")
wc_p=0
print ('p_bayes=%s' %(p_newins_p))
for i in range(0,g):
    for j in range(0,len(arr3)):
        if(e[i]==arr3[j]):
                #print ('%s %s' %(e[i],arr3[j]))
                #print (f[i])
                wc_p+=1
                if(f[i]>4):
                    p_newins_p+=float(arr4[j])
                else:
                    for i in range(0,(f[i])):
                        p_newins_p+=float(arr4[j])
                
#print(wc_p)
arr = []
arr2 = []
MyFile=open('Conditnal_probabilities_technology_2.txt','r')
total_count=0

for x in MyFile.read().split(';'):
    for y in x.split():
        if(total_count%2==0):
            narr = [y]
            arr = arr + narr
        else:
            narr2 = [y]
            arr2 = arr2 + narr2
            
        total_count = total_count+1;
        
#weight_matrix_t
arr3 = []
arr4 = []

MyFile=open('weightmatrix_t_2.txt','r')
total_count=0

for x in MyFile.read().split(';'):
    for y in x.split():
        if(total_count%2==0):
            narr = [y]
            arr3 = arr3 + narr
        else:
            narr2 = [y]
            arr4 = arr4 + narr2
            
        total_count = total_count+1;

#for technology
c_t=0
p_newins_t=0.0
for i in range(0,g):
    for j in range(0,len(arr)):
        if(e[i]==arr[j]):
                p_newins_t+= (10.0/50.0)*pow(float(arr2[j]),f[i])
                c_t+=1
#print ("  technology")
print ('t_bayes=%s' %(p_newins_t))
wc_t=0                
for i in range(0,g):
    for j in range(0,len(arr3)):
        if(e[i]==arr3[j]):
            if(f[i]>4):
                 p_newins_t+=float(arr4[j])
            else:
                 for i in range(0,(f[i])):
                    p_newins_t+=float(arr4[j])
                    
                
                    
                            
                                          
                
#print ('c_sp: %d %d ', (c_t,wc_t))
print ('sp=%s b=%s e=%s p=%s t=%s' %(p_newins_sp,p_newins_b,p_newins_e,p_newins_p,p_newins_t))
# Out:
# %s %f ('earlier', 0.000192492781520693)
# %s %f ('peopl', 0.00026948989412897017)
# %s %f ('use', 0.000384985563041386)
# %s %f ('year', 0.0006544754571703561)
# %s %f ('rival', 0.0006545421534180437)
# %s %f ('call', 0.0007700378223304595)
# %s %f ('chairman', 0.0008470349349387367)
# %s %f ('made', 0.0008470645777154867)
# %s %f ('summer', 0.0009240616903237639)
# %s %f ('look', 0.0010780559155403183)
# %s %f ('need', 0.0011550530281485955)
# %s %f ('sinc', 0.0013090472533651499)
# %s %f ('set', 0.001501540034885843)
# %s %f ('fan', 0.0016170357037982588)
# %s %f ('decis', 0.001886525597927229)
# %s %f ('accord', 0.0019635227105355064)
# %s %f ('expect', 0.002040519823143784)
# %s %f ('say', 0.0021560154920561994)
# %s %f ('said', 0.0021560238114341594)
# %s %f ('one', 0.002233020924042437)
# %s %f ('competit', 0.0023485165929548525)
# %s %f ('announc', 0.002464012261867268)
# %s %f ('first', 0.0024641308329742683)
# %s %f ('four', 0.0026566236144949613)
# %s %f ('make', 0.0026567421856019614)
# %s %f ('mani', 0.002772237854514377)
# %s %f ('still', 0.0029262320797309315)
# %s %f ('releas', 0.002926232079735325)
# %s %f ('also', 0.0029276845757960778)
# %s %f ('test', 0.003120177357316771)
# %s %f ('inform', 0.003197174469925048)
# %s %f ('work', 0.003312670138837464)
# %s %f ('won', 0.003505162920358157)
# %s %f ('the', 0.003505162934259374)
# %s %f ('chief', 0.0036206586031717895)
# %s %f ('end', 0.0038131513846924826)
# %s %f ('win', 0.004005644166213175)
# %s %f ('behind', 0.004082641278821453)
# %s %f ('would', 0.004506125398166977)
# %s %f ('next', 0.004583122510775255)
# %s %f ('window', 0.0045831521535520045)
# %s %f ('bid', 0.004814143491376836)
# %s %f ('held', 0.004891140603985113)
# %s %f ('report', 0.005083633385505806)
# %s %f ('appear', 0.005083633476802135)
# %s %f ('secur', 0.005083633476802135)
# %s %f ('issu', 0.005199129145714551)
# %s %f ('includ', 0.005276126258322828)
# %s %f ('new', 0.005276126258322828)
# %s %f ('success', 0.005353123370931106)
# %s %f ('month', 0.005353153013707855)
# %s %f ('tri', 0.005430150126316133)
# %s %f ('last', 0.005430624410744133)
# %s %f ('well', 0.005507621523352411)
# %s %f ('almost', 0.005584618635960688)
#
#
# sports
#
# sp_bayes=0.005584618635960688
# earlier earlier
# 0.00164782459279351847
# 1
# %s %f ('softwar', 0.007232443228754206)
# peopl peopl
# 0.00017995447686629820
# 1
# %s %f ('softwar', 0.007412397705620505)
# use use
# 0.00035990895373259641
# 1
# %s %f ('softwar', 0.007772306659353101)
# year year
# 0.00107972686119778933
# 1
# %s %f ('softwar', 0.008852033520550891)
# rival rival
# 0.00259586760070016189
# 2
# %s %f ('earlier', 0.014043768721951214)
# call call
# 0.00082391229639675924
# 1
# %s %f ('softwar', 0.014867681018347973)
# chairman chairman
# 0.00129793380035008094
# 1
# %s %f ('softwar', 0.016165614818698056)
# made made
# 0.00017995447686629820
# 2
# %s %f ('earlier', 0.016525523772430654)
# summer summer
# 0.00129793380035008094
# 1
# %s %f ('softwar', 0.017823457572780737)
# look look
# 0.00053986343059889467
# 1
# %s %f ('softwar', 0.018363321003379632)
# need need
# 0.00017995447686629820
# 1
# %s %f ('softwar', 0.01854327548024593)
# sinc sinc
# 0.00053986343059889467
# 1
# %s %f ('softwar', 0.019083138910844826)
# set set
# 0.00071981790746519282
# 1
# %s %f ('softwar', 0.01980295681831002)
# fan fan
# 0.00259586760070016189
# 1
# %s %f ('softwar', 0.022398824419010182)
# decis decis
# 0.00247173688919027782
# 1
# %s %f ('softwar', 0.02487056130820046)
# accord accord
# 0.00017995447686629820
# 1
# %s %f ('softwar', 0.02505051578506676)
# expect expect
# 0.00041195614819837962
# 1
# %s %f ('softwar', 0.02546247193326514)
# say say
# 0.00035990895373259641
# 1
# %s %f ('softwar', 0.025822380886997735)
# said said
# 0.00305922610672706942
# 3
# %s %f ('scare', 0.03500005920717894)
# one one
# 0.00017995447686629820
# 1
# %s %f ('softwar', 0.03518001368404524)
# competit competit
# 0.00259586760070016189
# 1
# %s %f ('softwar', 0.037775881284745405)
# announc announc
# 0.00035990895373259641
# 1
# %s %f ('softwar', 0.038135790238478004)
# first first
# 0.00053986343059889467
# 2
# %s %f ('earlier', 0.03921551709967579)
# earlier earlier
# 0.00164782459279351847
# 1
# %s %f ('softwar', 0.04086334169246931)
# four four
# 0.00071981790746519282
# 1
# %s %f ('softwar', 0.0415831595999345)
# make make
# 0.00053986343059889467
# 2
# %s %f ('earlier', 0.04266288646113228)
# earlier earlier
# 0.00164782459279351847
# 1
# %s %f ('softwar', 0.044310711053925804)
# mani mani
# 0.00082391229639675924
# 1
# %s %f ('softwar', 0.04513462335032256)
# still still
# 0.00221683241582456897
# 1
# %s %f ('softwar', 0.04735145576614713)
# releas releas
# 0.00073894413860818966
# 4
# %s %f ('thi', 0.0503072323205799)
# also also
# 0.00233940819926187682
# 2
# %s %f ('earlier', 0.05498604871910366)
# earlier earlier
# 0.00164782459279351847
# 1
# %s %f ('softwar', 0.05663387331189718)
# test test
# 0.00295577655443275862
# 1
# %s %f ('softwar', 0.05958964986632994)
# inform inform
# 0.00017995447686629820
# 1
# %s %f ('softwar', 0.05976960434319624)
# work work
# 0.00035990895373259641
# 1
# %s %f ('softwar', 0.06012951329692884)
# won won
# 0.00519173520140032378
# 1
# %s %f ('softwar', 0.06532124849832917)
# the the
# 0.00251936267612817453
# 4
# %s %f ('thi', 0.07539869920284188)
# chief chief
# 0.00035990895373259641
# 1
# %s %f ('softwar', 0.07575860815657448)
# end end
# 0.00071981790746519282
# 1
# %s %f ('softwar', 0.07647842606403968)
# win win
# 0.00164782459279351847
# 1
# %s %f ('softwar', 0.0781262506568332)
# behind behind
# 0.00041195614819837962
# 1
# %s %f ('softwar', 0.07853820680503157)
# would would
# 0.00179954476866298193
# 1
# %s %f ('softwar', 0.08033775157369455)
# next next
# 0.00041195614819837962
# 1
# %s %f ('softwar', 0.08074970772189292)
# window window
# 0.00129793380035008094
# 2
# %s %f ('earlier', 0.08334557532259308)
# earlier earlier
# 0.00164782459279351847
# 1
# %s %f ('softwar', 0.0849933999153866)
# bid bid
# 0.00648966900175040450
# 1
# %s %f ('softwar', 0.091483068917137)
# held held
# 0.00073894413860818966
# 1
# %s %f ('softwar', 0.09222201305574519)
# report report
# 0.00071981790746519282
# 1
# %s %f ('softwar', 0.09294183096321039)
# appear appear
# 0.00123586844459513891
# 3
# %s %f ('scare', 0.09664943629699581)
# secur secur
# 0.00041195614819837962
# 7
# secur
# %s %f ('secur', 0.09706139244519418)
# issu issu
# 0.00147788827721637931
# 1
# %s %f ('softwar', 0.09853928072241057)
# includ includ
# 0.00017995447686629820
# 1
# %s %f ('softwar', 0.09871923519927686)
# new new
# 0.00071981790746519282
# 6
# new
# %s %f ('new', 0.09943905310674206)
# success success
# 0.00041195614819837962
# 1
# %s %f ('softwar', 0.09985100925494043)
# month month
# 0.00073894413860818966
# 2
# %s %f ('earlier', 0.1013288975321568)
# earlier earlier
# 0.00164782459279351847
# 1
# %s %f ('softwar', 0.10297672212495032)
# tri tri
# 0.00041195614819837962
# 1
# %s %f ('softwar', 0.1033886782731487)
# last last
# 0.00125968133806408727
# 2
# %s %f ('earlier', 0.10590804094927687)
# well well
# 0.00041195614819837962
# 1
# %s %f ('softwar', 0.10631999709747525)
# almost almost
# 0.00129793380035008094
# 1
# %s %f ('softwar', 0.10761793089782533)
#
# %s %f ('softwar', 0.10761793089782533)
# b_bayes=0.008314357197920893
# e_bayes=0.007822330237432503
# p_bayes=0.008984473505915247
# t_bayes=0.011686979730729338
# sp=0.10761793089782533 b=0.14615748573494897 e=0.13271861649450142 p=0.12574625072933712 t=0.3930386560329973

# %%
sp_bayes=0.002711548901091419
b_bayes=0.005325743404330377
e_bayes=0.0033737195555376934
p_bayes=0.005308423665233377
t_bayes=0.005142217824414049
sp=0.04176453141427378 b=0.10767199764219915 e=0.06138459391935551 p=0.09397509693664943 t=0.12152855834036291
read_data=filter(str.isalnum,read_data)    
stop_words=set(stopwords.words("english"))
#filtered_sentence=[]word_list
filtered_sentence=[w for w in read_data if not w in stop_words]
path = 'C:\\Users\\ret'
os.chdir(path)

filtered_sentence=[item.lower() for item in filtered_sentence]
filtered_sentence=[x for x in filtered_sentence if not x.isdigit()]
    
for words in filtered_sentence:
    if ( len(words)==1 ) :
        filtered_sentence.remove(words)
for x in filtered_sentence:
    if ( len(x)==2 ) :
        filtered_sentence.remove(x)
