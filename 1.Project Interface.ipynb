# %%
import re
from operator import itemgetter
from collections import OrderedDict
from collections import Counter
import nltk
from nltk.tokenize import word_tokenize,sent_tokenize
from nltk.corpus import stopwords
from nltk.stem.lancaster import LancasterStemmer
from nltk.stem import PorterStemmer
from collections import Counter
from collections import defaultdict
from tkinter import *
from tkinter.filedialog   import askopenfilename 
import string
import random


root = Tk()
root.geometry("1350x700+0+0")
root.title("English Text Categorize System")

tops = Frame(root,width = 1350,height = 50 , bg = "powder blue", relief = FLAT)
tops.pack(side = TOP)

f1 = Frame(root,width = 1330,height = 60, relief = FLAT)
f1.pack(side = TOP)
f2 = Frame(root,width = 1330,height =900 , bg = "powder blue", relief = FLAT)
f2.pack(side=TOP)
f3 = Frame(root,width = 1330,height =60 , bg = "powder blue", relief = FLAT)
f3.pack(side=BOTTOM)

lblInfo = Label(tops,font = ('times new roman',50,'bold'),text= "English Text Categorize  System(NB)",fg="Steel Blue",bd=10,anchor='nw')
lblInfo.grid(row=0,column=0)

st=PorterStemmer()

def compil(): 
    with open(name) as f:
         read_data = word_tokenize(f.read())         
    quote = read_data
    T.delete('1.0',END)
    T.insert(END, quote) 
    stop_words=set(stopwords.words("english"))
    filtered_sentence=[w for w in read_data if not w in stop_words]
    fh1=open("file_corpus_S507.txt","w")
    filtered_sentence=[item.lower() for item in filtered_sentence]
    filtered_sentence=[x for x in filtered_sentence if not x.isdigit()]
    for words in filtered_sentence:
        if ( len(words)==1 ) :
            filtered_sentence.remove(words)
    for w in  filtered_sentence:
        fh1.write(st.stem(w)+ ' ')
    fh1.close()
    e=[]
    f=[]
    count={}
    for w in open('file_corpus_S507.txt').read().split():
        if w in count:
            count[w]+=1
        else:
            count[w]=1
    for word,times in count.items():
        e.append(word)
        f.append(times)    
    g=len(f) 
    arr = []      #............................................................Here Starting Sports 
    arr2 = []
    MyFile=open('Conditnal_probabilities_sport_1.txt','r')
    total_count=0
    for x in MyFile.read().split(';'):
        for y in x.split():
            if(total_count%2==0):
                narr = [y]
                arr = arr + narr
            else:
                narr2 = [y]
                arr2 = arr2 + narr2
            total_count = total_count+1;
    arr3 = [] #....................................................................weight_matrix_sp
    arr4 = []
    MyFile=open('weightmatrix_sp_.txt','r')
    total_count=0
    for x in MyFile.read().split(';'):
        for y in x.split():
            if(total_count%2==0):
                narr = [y]
                arr3 = arr3 + narr
            else:
                narr2 = [y]
                arr4 = arr4 + narr2
            total_count = total_count+1;
    p_newins_sp1=0.0           #..........................................................for sports:
    for i in range(0,g):
        for j in range(0,len(arr)):
            if(e[i]==arr[j]):
                    p_newins_sp1+= (7.0/20.0)*pow(float(arr2[j]),f[i])
                    
    p_newins_sp= p_newins_sp1;
    for i in range(0,g):
        for j in range(0,len(arr3)):
            if(e[i]==arr3[j]):
                    p_newins_sp+= float(arr4[j])
    arr = []       #.........................................................Here Starting ENTERTAINMENT
    arr2 = []
    MyFile=open('Conditnal_probabilities_entertainment_1.txt','r')
    total_count=0
    for x in MyFile.read().split(';'):
        for y in x.split():
            if(total_count%2==0):
                narr = [y]
                arr = arr + narr
            else:
                narr2 = [y]
                arr2 = arr2 + narr2
            total_count = total_count+1;
    arr3 = []    #....................................................................weight_matrix_e
    arr4 = []
    MyFile=open('weightmatrix_e_.txt','r')
    total_count=0
    for x in MyFile.read().split(';'):
        for y in x.split():
            if(total_count%2==0):
                narr = [y]
                arr3 = arr3 + narr
            else:
                narr2 = [y]
                arr4 = arr4 + narr2
            total_count = total_count+1;
    p_newins_e1=0.0      #..............................................................for ENTERTAINMENT
    for i in range(0,g):
        for j in range(0,len(arr)):
                if(e[i]==arr[j]):
                    p_newins_e1+= (7.0/20.0)* pow(float(arr2[j]),f[i])
    p_newins_e= p_newins_e1;
    for i in range(0,g):
        for j in range(0,len(arr3)):
            if(e[i]==arr3[j]):
                    p_newins_e+= float(arr4[j])
    arr = []       #.............................................................Here starting business
    arr2 = []
    MyFile=open('Conditnal_probabilities_bussiness_1.txt','r')
    total_count=0
    for x in MyFile.read().split(';'):
        for y in x.split():
            if(total_count%2==0):
                narr = [y]
                arr = arr + narr
            else:
                narr2 = [y]
                arr2 = arr2 + narr2
            total_count = total_count+1;
    arr3 = []          #...............................................................weight_matrix_b
    arr4 = []
    MyFile=open('weightmatrix_b_.txt','r')
    total_count=0
    for x in MyFile.read().split(';'):
        for y in x.split():
            if(total_count%2==0):
                narr = [y]
                arr3 = arr3 + narr
            else:
                narr2 = [y]
                arr4 = arr4 + narr2
            total_count = total_count+1;
    p_newins_b1=0.0      #................................................................for business
    for i in range(0,g):
        for j in range(0,len(arr)):
              if(e[i]==arr[j]):
                    p_newins_b1+= (6.0/20.0)* pow(float(arr2[j]),f[i])  
    p_newins_b= p_newins_b1;
    #print  (p_newins_b)
    for i in range(0,g):
        for j in range(0,len(arr3)):
            if(e[i]==arr3[j]):
                    p_newins_b+=float(arr4[j])
    arr = []       #...........................................................Here starting technology
    arr2 = []
    MyFile=open('Conditnal_probabilities_technology_1.txt','r')
    total_count=0
    for x in MyFile.read().split(';'):
        for y in x.split():
            if(total_count%2==0):
                narr = [y]
                arr = arr + narr
            else:
                narr2 = [y]
                arr2 = arr2 + narr2
            total_count = total_count+1;   
    arr3 = []   #......................................................................weight_matrix_t
    arr4 = []
    MyFile=open('weightmatrix_t_.txt','r')
    total_count=0
    for x in MyFile.read().split(';'):
        for y in x.split():
            if(total_count%2==0):
                narr = [y]
                arr3 = arr3 + narr
            else:
                narr2 = [y]
                arr4 = arr4 + narr2
            total_count = total_count+1;    
    c_t=0       #.......................................................................for technology
    p_newins_t1=0.0
    for i in range(0,g):
        for j in range(0,len(arr)):
              if(e[i]==arr[j]):
                    c_t+=1
                    p_newins_t1+= (8.0/39.0)* pow(float(arr2[j]),f[i])
    #print ("  technology")
    #print ( p_newins_t)
    p_newins_t= p_newins_t1; 
    wc_t=0                
    for i in range(0,g):
        for j in range(0,len(arr3)):
            if(e[i]==arr3[j]):
                    #print ('%s %s' %(e[i],arr3[j]))
                    wc_t+=1
                    #print (arr4[j])
                    p_newins_t+= (float(arr4[j]))
    arr = []     #............................................................................Here Starting politics
    arr2 = []
    MyFile=open('Conditnal_probabilities_politics_1.txt','r')
    total_count=0
    for x in MyFile.read().split(';'):
        for y in x.split():
            if(total_count%2==0):
                narr = [y]
                arr = arr + narr
            else:
                narr2 = [y]
                arr2 = arr2 + narr2
            total_count = total_count+1;   
    arr3 = []       #..........................................................................weight_matrix_p
    arr4 = []
    MyFile=open('weightmatrix_p_.txt','r')
    total_count=0
    for x in MyFile.read().split(';'):
        for y in x.split():
            if(total_count%2==0):
                narr = [y]
                arr3 = arr3 + narr
            else:
                narr2 = [y]
                arr4 = arr4 + narr2
            total_count = total_count+1;   
    p_newins_p1=0.0   #.............................................................................for politics
    for i in range(0,g):
        for j in range(0,len(arr)):
              if(e[i]==arr[j]):
                    p_newins_p1+=(8.0/39.0)* pow(float(arr2[j]),f[i])
                    
    p_newins_p= p_newins_p1;
    #print ( p_newins_p)
    for i in range(0,g):
        for j in range(0,len(arr3)):
            if(e[i]==arr3[j]):
                   # print ('%s %s' %(e[i],arr3[j]))
                    #print (arr4[j])
                    p_newins_p+= (float(arr4[j]))    
             
    print ('%s %s %s %s %s' %(p_newins_sp,p_newins_e,p_newins_b,p_newins_t,p_newins_p))
    print ('%s %s %s %s %s' %(p_newins_sp1,p_newins_e1,p_newins_b1,p_newins_t1,p_newins_p1))
    
    
    
    global lvl2Text
    global lvl3Text
    global lvl4Text
    global lvl5Text
    global lvl6Text   
    global lvl2_sp1Text
    global lvl3_e1Text
    global lvl4_b1Text
    global lvl5_t1Text
    global lvl6_p1Text
    global lvl_r1Text
    global lvl_r2Text
    
    lvl2Text = StringVar()
    lvl3Text = StringVar()
    lvl4Text = StringVar()
    lvl5Text = StringVar()
    lvl6Text = StringVar()
    lvl2_sp1Text = StringVar()
    lvl3_e1Text = StringVar()
    lvl4_b1Text = StringVar()
    lvl5_t1Text = StringVar()
    lvl6_p1Text = StringVar()
    lvl_r1Text = StringVar()
    lvl_r2Text = StringVar()
    
    lvl2Text.set(p_newins_sp)
    lvl3Text.set(p_newins_e)
    lvl4Text.set(p_newins_b)
    lvl5Text.set(p_newins_t)
    lvl6Text.set(p_newins_p)
    lvl2_sp1Text.set(p_newins_sp1)
    lvl3_e1Text.set(p_newins_e1)
    lvl4_b1Text.set(p_newins_b1)
    lvl5_t1Text.set(p_newins_t1)
    lvl6_p1Text.set(p_newins_p1)
    
    
    Find4.config(textvariable=lvl2Text)
    Find5.config(textvariable=lvl3Text)
    Find6.config(textvariable=lvl4Text)
    Find7.config(textvariable=lvl5Text)
    Find8.config(textvariable=lvl6Text)
    Find4_sp1.config(textvariable=lvl2_sp1Text)
    Find5_e1.config(textvariable=lvl3_e1Text)
    Find6_b1.config(textvariable=lvl4_b1Text)
    Find7_t1.config(textvariable=lvl5_t1Text)
    Find8_p1.config(textvariable=lvl6_p1Text)
    
    #def shortBubbleSort(alist):
    #   exchanges = True
    #   passnum = len(alist)-1
    #   while passnum > 0 and exchanges:
    #        exchanges = False
    #        for i in range(passnum):
    #            if alist[i]<alist[i+1]:
    #                exchanges = True
    #                temp = alist[i]
    #                alist[i] = alist[i+1]
    #                alist[i+1] = temp
    #        passnum = passnum-1
            
    dict={'SPORTS':p_newins_sp,'ENTERTAINMENT':p_newins_e,'BUSINESS':p_newins_b,'TECHNOLOGY':p_newins_t,'POLITICS':p_newins_p}
    #sorted_dict = sorted(dict.items(), key=operator.itemgetter(1))
    #sorted_dict = OrderedDict(sorted(dict.items(), key=itemgetter(0)))
    # print(dict)
    #c=Counter(dict)
    #shortBubbleSort(alist)
    
    dict2=sorted(dict.values())
    #print(dict) 
    dic=sorted(dict, key=dict.__getitem__, reverse=True)
    #print(dic)
    
    #alist=[p_newins_sp,p_newins_e,p_newins_b,p_newins_t,p_newins_p]
    #shortBubbleSort(alist)
    lvl_r1Text.set(dic[0])
    Find9_r1.config(textvariable=lvl_r1Text)
    #print(alist)
    
    dict={'SPORTS':p_newins_sp1,'ENTERTAINMENT':p_newins_e1,'BUSINESS':p_newins_b1,'TECHNOLOGY':p_newins_t1,'POLITICS':p_newins_p1}
    dict2=sorted(dict.values())
    dic=sorted(dict, key=dict.__getitem__, reverse=True)
    
    #alist=[p_newins_sp1,p_newins_e1,p_newins_b1,p_newins_t1,p_newins_p1]
    #shortBubbleSort(alist)
    lvl_r2Text.set(dic[0])
    #print(alist)
    Find9_r2.config(textvariable=lvl_r2Text)
    
def qExit():
    root.destroy()  
def Reset():
    lvl1Text.set("")
    lvl2Text.set("")
    lvl3Text.set("")
    lvl4Text.set("")
    lvl5Text.set("")
    lvl6Text.set("")
    lvl2_sp1Text.set("")
    lvl3_e1Text.set("")
    lvl4_b1Text.set("")
    lvl5_t1Text.set("")
    lvl6_p1Text.set("")
    lvl_r1Text.set("")
    lvl_r2Text.set("") 
    T.delete('1.0',END)
def callback():
    global lvl1Text
    global name
    name = askopenfilename() 
    ns = name.split('/')
    name = ns[len(ns)-1]    
    lvl1Text = StringVar()
    lvl1Text.set(name)
    Find2.config(textvariable=lvl1Text)
    with open(name) as f:
         read_data = word_tokenize(f.read())         
    quote = read_data
    lvl2Text.set("")
    lvl3Text.set("")
    lvl4Text.set("")
    lvl5Text.set("")
    lvl6Text.set("")
    lvl2_sp1Text.set("")
    lvl3_e1Text.set("")
    lvl4_b1Text.set("")
    lvl5_t1Text.set("")
    lvl6_p1Text.set("")
    lvl_r1Text.set("")
    lvl_r2Text.set("")              
    T.delete('1.0',END)
    T.insert(END, quote)     


                    
#errmsg = 'Error!'
Find1=Label(f1,font=('times new roman',16,'bold'),text="FIND FILE",fg="Steel Blue",bd=16,anchor='nw')
Find1.grid(row=1,column=0)
btn1=Button(f1,text='FILE OPEN', command=callback,padx=4,pady=4,bd=4,fg='black',font=('times new roman',10,'bold')).grid(row=1,column=1)

Find2=Label(f1,font=('times new roman',16,'bold'),text="",fg="Red",bd=16,anchor='nw')
Find2.grid(row=1,column=2)
Find3=Label(f1,font=('times new roman',16,'bold'),text="COMPILE",fg="Steel Blue",bd=16,anchor='nw')
Find3.grid(row=1,column=3)
btn2=Button(f1,text='COMPILE', command=compil,padx=4,pady=4,bd=4,fg='black',font=('times new roman',10,'bold')).grid(row=1,column=4)
btn3=Button(f1,text='RESET', command=Reset,padx=4,pady=4,bd=4,fg='black',font=('times new roman',10,'bold')).grid(row=1,column=5)
btn4=Button(f1,text='EXIT', command=qExit,padx=4,pady=4,bd=4,fg='black',font=('times new roman',10,'bold')).grid(row=1,column=6)
T = Text(f2, height=13, width=160,padx=30, pady=30,font=('times new roman',11,'bold'))
T.pack()

# S = Scrollbar(f2)
# T = Text(f2, height=16, width=170,padx=30, pady=30,font=('times new roman',11,'bold'))
# S.pack(side=RIGHT)
# T.pack(side=LEFT)
# S.config(command=T.yview)
# T.config(yscrollcommand=S.set)

labelframe = LabelFrame(f2, text="OUTPUT",padx=20, pady=20,fg="Steel Blue",font=('times new roman',11,'bold'))
labelframe.pack(fill=X)


Find40=Label(labelframe,font=('times new roman',10,'bold'),text="WIGHT MATRIX",fg="Red",bd=16,anchor='nw')
Find40.grid(row=2,column=0)
Find41=Label(labelframe,font=('times new roman',10,'bold'),text="SPORTS",fg="Steel Blue",bd=16,anchor='nw')
Find41.grid(row=2,column=1)
Find40=Label(labelframe,font=('times new roman',10,'bold'),text="WITH",fg="Red",bd=16,anchor='nw')
Find40.grid(row=3,column=0)
Find4=Label(labelframe,font=('times new roman',10,'bold'),text="",bd=16,anchor='nw')
Find4.grid(row=3,column=1)
Find4_sp1=Label(labelframe,font=('times new roman',10,'bold'),text="",bd=16,anchor='nw')
Find40=Label(labelframe,font=('times new roman',10,'bold'),text="WITHOUT",fg="Red",bd=16,anchor='nw')
Find40.grid(row=4,column=0)
Find4_sp1.grid(row=4,column=1)
Find51=Label(labelframe,font=('times new roman',10,'bold'),text="ENTERTAINMENT",fg="Steel Blue",bd=16,anchor='nw')
Find51.grid(row=2,column=2)
Find5=Label(labelframe,font=('times new roman',10,'bold'),text="",bd=16,anchor='nw')
Find5.grid(row=3,column=2)
Find5_e1=Label(labelframe,font=('times new roman',10,'bold'),text="",bd=16,anchor='nw')
Find5_e1.grid(row=4,column=2)
Find61=Label(labelframe,font=('times new roman',10,'bold'),text="BUSINESS",fg="Steel Blue",bd=16,anchor='nw')
Find61.grid(row=2,column=3)
Find6=Label(labelframe,font=('times new roman',10,'bold'),text="",bd=16,anchor='nw')
Find6.grid(row=3,column=3)
Find6_b1=Label(labelframe,font=('times new roman',10,'bold'),text="",bd=16,anchor='nw')
Find6_b1.grid(row=4,column=3)
Find71=Label(labelframe,font=('times new roman',10,'bold'),text="TECHNOLOGY",fg="Steel Blue",bd=16,anchor='nw')
Find71.grid(row=2,column=4)
Find7=Label(labelframe,font=('times new roman',10,'bold'),text="",bd=16,anchor='nw')
Find7.grid(row=3,column=4)
Find7_t1=Label(labelframe,font=('times new roman',10,'bold'),text="",bd=16,anchor='nw')
Find7_t1.grid(row=4,column=4)
Find81=Label(labelframe,font=('times new roman',10,'bold'),text="POLITICS",fg="Steel Blue",bd=16,anchor='nw')
Find81.grid(row=2,column=5)
Find8=Label(labelframe,font=('times new roman',10,'bold'),text="",bd=16,anchor='nw')
Find8.grid(row=3,column=5)
Find8_p1=Label(labelframe,font=('times new roman',10,'bold'),text="",bd=16,anchor='nw')
Find8_p1.grid(row=4,column=5)

Find9_r=Label(labelframe,font=('times new roman',10,'bold'),text="RESULT",fg="Red",bd=16,anchor='nw')
Find9_r.grid(row=2,column=6) 
Find9_r1=Label(labelframe,font=('times new roman',14,'bold'),text="",fg="Red",bd=16,anchor='nw')
Find9_r1.grid(row=3,column=6)
Find9_r2=Label(labelframe,font=('times new roman',14,'bold'),text="",fg="Red",bd=16,anchor='nw')
Find9_r2.grid(row=4,column=6)

Riaydh=Label(f3,font=('times new roman',10,'bold'),text="DEVELOPED BY RIAYDH & SHATHI",fg="Red",bd=16,anchor='nw')
Riaydh.grid(row=4,column=4)
#Button(text='File Open', command=callback).pack(fill=x)
mainloop()
# Out:
# 0.056412984978200485 0.06076511688570927 0.03924699965318509 0.06534502863711603 0.04821068942025083
# 0.005986147440181209 0.0051301299489642255 0.003965941496845198 0.004813753057069529 0.0036311883850991765
