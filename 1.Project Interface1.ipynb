# %%
# import re
import nltk
from nltk.tokenize import word_tokenize,sent_tokenize
from nltk.corpus import stopwords
from nltk.stem.lancaster import LancasterStemmer
from nltk.stem import PorterStemmer
from collections import Counter
from collections import defaultdict
from tkinter import *
from tkinter.filedialog   import askopenfilename 
import string
import random


root = Tk()
root.geometry("1350x700+0+0")
root.title("Newspaper Categorize System")

tops = Frame(root,width = 1350,height = 50 , bg = "powder blue", relief = FLAT)
tops.pack(side = TOP)

f1 = Frame(root,width = 1330,height = 60, relief = FLAT)
f1.pack(side = TOP)
f2 = Frame(root,width = 1330,height =900 , bg = "powder blue", relief = FLAT)
f2.pack(side=TOP)
f3 = Frame(root,width = 1330,height =60 , bg = "powder blue", relief = FLAT)
f3.pack(side=BOTTOM)

lblInfo = Label(tops,font = ('times new roman',50,'bold'),text= "Newspaper Categorize  System(NB)",fg="Steel Blue",bd=10,anchor='nw')
lblInfo.grid(row=0,column=0)

st=PorterStemmer()

def compil(): 
    with open(name) as f:
         read_data = word_tokenize(f.read())         
    quote = read_data
    T.delete('1.0',END)
    T.insert(END, quote) 
    stop_words=set(stopwords.words("english"))
    filtered_sentence=[w for w in read_data if not w in stop_words]
    fh1=open("file_corpus_S507.txt","w")
    filtered_sentence=[item.lower() for item in filtered_sentence]
    filtered_sentence=[x for x in filtered_sentence if not x.isdigit()]
    for words in filtered_sentence:
        if ( len(words)==1 ) :
            filtered_sentence.remove(words)
    for w in  filtered_sentence:
        fh1.write(st.stem(w)+ ' ')
    fh1.close()
    e=[]
    f=[]
    count={}
    for w in open('file_corpus_S507.txt').read().split():
        if w in count:
            count[w]+=1
        else:
            count[w]=1
    for word,times in count.items():
        e.append(word)
        f.append(times)    
    g=len(f) 
    arr = []      #...........................................................Here Starting Sports 
    arr2 = []
    MyFile=open('Conditnal_probabilities_sport_1.txt','r')
    total_count=0
    for x in MyFile.read().split(';'):
        for y in x.split():
            if(total_count%2==0):
                narr = [y]
                arr = arr + narr
            else:
                narr2 = [y]
                arr2 = arr2 + narr2
            total_count = total_count+1;
    arr3 = [] #....................................................................weight_matrix_sp
    arr4 = []
    MyFile=open('weightmatrix_sp_.txt','r')
    total_count=0
    for x in MyFile.read().split(';'):
        for y in x.split():
            if(total_count%2==0):
                narr = [y]
                arr3 = arr3 + narr
            else:
                narr2 = [y]
                arr4 = arr4 + narr2
            total_count = total_count+1;
    p_newins_sp1=0.0           #..........................................................for sports:
    for i in range(0,g):
        for j in range(0,len(arr)):
            if(e[i]==arr[j]):
                    p_newins_sp1+= (7.0/20.0)*pow(float(arr2[j]),f[i])
                    
    p_newins_sp= p_newins_sp1;
    for i in range(0,g):
        for j in range(0,len(arr3)):
            if(e[i]==arr3[j]):
                    p_newins_sp+= float(arr4[j])
    arr = []       #.........................................................Here Starting ENTERTAINMENT
    arr2 = []
    MyFile=open('Conditnal_probabilities_entertainment_1.txt','r')
    total_count=0
    for x in MyFile.read().split(';'):
        for y in x.split():
            if(total_count%2==0):
                narr = [y]
                arr = arr + narr
            else:
                narr2 = [y]
                arr2 = arr2 + narr2
            total_count = total_count+1;
    arr3 = []    #....................................................................weight_matrix_e
    arr4 = []
    MyFile=open('weightmatrix_e_.txt','r')
    total_count=0
    for x in MyFile.read().split(';'):
        for y in x.split():
            if(total_count%2==0):
                narr = [y]
                arr3 = arr3 + narr
            else:
                narr2 = [y]
                arr4 = arr4 + narr2
            total_count = total_count+1;
    p_newins_e1=0.0      #..............................................................for ENTERTAINMENT
    for i in range(0,g):
        for j in range(0,len(arr)):
                if(e[i]==arr[j]):
                    p_newins_e1+= (7.0/20.0)* pow(float(arr2[j]),f[i])
    p_newins_e= p_newins_e1;
    for i in range(0,g):
        for j in range(0,len(arr3)):
            if(e[i]==arr3[j]):
                    p_newins_e+= float(arr4[j])
    arr = []       #.............................................................Here starting business
    arr2 = []
    MyFile=open('Conditnal_probabilities_bussiness_1.txt','r')
    total_count=0
    for x in MyFile.read().split(';'):
        for y in x.split():
            if(total_count%2==0):
                narr = [y]
                arr = arr + narr
            else:
                narr2 = [y]
                arr2 = arr2 + narr2
            total_count = total_count+1;
    arr3 = []          #...............................................................weight_matrix_b
    arr4 = []
    MyFile=open('weightmatrix_b_.txt','r')
    total_count=0
    for x in MyFile.read().split(';'):
        for y in x.split():
            if(total_count%2==0):
                narr = [y]
                arr3 = arr3 + narr
            else:
                narr2 = [y]
                arr4 = arr4 + narr2
            total_count = total_count+1;
    p_newins_b1=0.0      #................................................................for business
    for i in range(0,g):
        for j in range(0,len(arr)):
              if(e[i]==arr[j]):
                    p_newins_b1+= (6.0/20.0)* pow(float(arr2[j]),f[i])  
    p_newins_b= p_newins_b1;
    #print  (p_newins_b)
    for i in range(0,g):
        for j in range(0,len(arr3)):
            if(e[i]==arr3[j]):
                    p_newins_b+=float(arr4[j])
    arr = []       #...........................................................Here starting technology
    arr2 = []
    MyFile=open('Conditnal_probabilities_technology_1.txt','r')
    total_count=0
    for x in MyFile.read().split(';'):
        for y in x.split():
            if(total_count%2==0):
                narr = [y]
                arr = arr + narr
            else:
                narr2 = [y]
                arr2 = arr2 + narr2
            total_count = total_count+1;   
    arr3 = []   #......................................................................weight_matrix_t
    arr4 = []
    MyFile=open('weightmatrix_t_.txt','r')
    total_count=0
    for x in MyFile.read().split(';'):
        for y in x.split():
            if(total_count%2==0):
                narr = [y]
                arr3 = arr3 + narr
            else:
                narr2 = [y]
                arr4 = arr4 + narr2
            total_count = total_count+1;    
    c_t=0       #.......................................................................for technology
    p_newins_t1=0.0
    for i in range(0,g):
        for j in range(0,len(arr)):
              if(e[i]==arr[j]):
                    c_t+=1
                    p_newins_t1+= (8.0/39.0)* pow(float(arr2[j]),f[i])
    #print ("  technology")
    #print ( p_newins_t)
    p_newins_t= p_newins_t1; 
    wc_t=0                
    for i in range(0,g):
        for j in range(0,len(arr3)):
            if(e[i]==arr3[j]):
                    #print ('%s %s' %(e[i],arr3[j]))
                    wc_t+=1
                    #print (arr4[j])
                    p_newins_t+= (float(arr4[j]))
    arr = []     #............................................................................Here Starting politics
    arr2 = []
    MyFile=open('Conditnal_probabilities_politics_1.txt','r')
    total_count=0
    for x in MyFile.read().split(';'):
        for y in x.split():
            if(total_count%2==0):
                narr = [y]
                arr = arr + narr
            else:
                narr2 = [y]
                arr2 = arr2 + narr2
            total_count = total_count+1;   
    arr3 = []       #..........................................................................weight_matrix_p
    arr4 = []
    MyFile=open('weightmatrix_p_.txt','r')
    total_count=0
    for x in MyFile.read().split(';'):
        for y in x.split():
            if(total_count%2==0):
                narr = [y]
                arr3 = arr3 + narr
            else:
                narr2 = [y]
                arr4 = arr4 + narr2
            total_count = total_count+1;   
    p_newins_p1=0.0   #.............................................................................for politics
    for i in range(0,g):
        for j in range(0,len(arr)):
              if(e[i]==arr[j]):
                    p_newins_p1+=(8.0/39.0)* pow(float(arr2[j]),f[i])
                    
    p_newins_p= p_newins_p1;
    #print ( p_newins_p)
    for i in range(0,g):
        for j in range(0,len(arr3)):
            if(e[i]==arr3[j]):
                   # print ('%s %s' %(e[i],arr3[j]))
                    #print (arr4[j])
                    p_newins_p+= (float(arr4[j]))    
             
    print ('%s %s %s %s %s' %(p_newins_sp,p_newins_e,p_newins_b,p_newins_t,p_newins_p))
    print ('%s %s %s %s %s' %(p_newins_sp1,p_newins_e1,p_newins_b1,p_newins_t1,p_newins_p1))
    global lvl2Text
    global lvl3Text
    global lvl4Text
    global lvl5Text
    global lvl6Text
    lvl2Text = StringVar()
    lvl3Text = StringVar()
    lvl4Text = StringVar()
    lvl5Text = StringVar()
    lvl6Text = StringVar()
    lvl2Text.set(p_newins_sp)
    lvl3Text.set(p_newins_e)
    lvl4Text.set(p_newins_b)
    lvl5Text.set(p_newins_t)
    lvl6Text.set(p_newins_p)
    Find4.config(textvariable=lvl2Text)
    Find5.config(textvariable=lvl3Text)
    Find6.config(textvariable=lvl4Text)
    Find7.config(textvariable=lvl5Text)
    Find8.config(textvariable=lvl6Text)
    lvl2Text = StringVar()
    lvl3Text = StringVar()
    lvl4Text = StringVar()
    lvl5Text = StringVar()
    lvl6Text = StringVar()
    lvl2Text.set(p_newins_sp1)
    lvl3Text.set(p_newins_e1)
    lvl4Text.set(p_newins_b1)
    lvl5Text.set(p_newins_t1)
    lvl6Text.set(p_newins_p1)
    Find4_sp1.config(textvariable=lvl2Text)
    Find5_e1.config(textvariable=lvl3Text)
    Find6_b1.config(textvariable=lvl4Text)
    Find7_t1.config(textvariable=lvl5Text)
    Find8_p1.config(textvariable=lvl6Text)

    
def qExit():
    root.destroy()  
def Reset():
    lvl1Text.set("")
    lvl2Text.set("")
    lvl3Text.set("")
    lvl4Text.set("")
    lvl5Text.set("")
    lvl6Text.set("")
    T.delete('1.0',END)
def callback():
    global name
    global lvl1Text
    name = askopenfilename() 
    ns = name.split('/')
    name = ns[len(ns)-1]
    lvl1Text = StringVar()
    lvl1Text.set(name)
    Find2.config(textvariable=lvl1Text)
    with open(name) as f:
         read_data = word_tokenize(f.read())         
    quote = read_data
    T.delete('1.0',END)
    T.insert(END, quote)
    lvl2Text.set("")
    lvl3Text.set("")
    lvl4Text.set("")
    lvl5Text.set("")
    lvl6Text.set("")    

errmsg = 'Error!'
Find1=Label(f1,font=('times new roman',16,'bold'),text="FIND FILE",bd=16,anchor='nw')
Find1.grid(row=1,column=0)
btn1=Button(f1,text='FILE OPEN', command=callback,padx=4,pady=4,bd=4,fg='black',font=('times new roman',10,'bold')).grid(row=1,column=1)

Find2=Label(f1,font=('times new roman',16,'bold'),text="",bd=16,anchor='nw')
Find2.grid(row=1,column=2)
Find3=Label(f1,font=('times new roman',16,'bold'),text="COMPILE",bd=16,anchor='nw')
Find3.grid(row=1,column=3)
btn2=Button(f1,text='COMPILE', command=compil,padx=4,pady=4,bd=4,fg='black',font=('times new roman',10,'bold')).grid(row=1,column=4)
btn3=Button(f1,text='RESET', command=Reset,padx=4,pady=4,bd=4,fg='black',font=('times new roman',10,'bold')).grid(row=1,column=5)
btn4=Button(f1,text='EXIT', command=qExit,padx=4,pady=4,bd=4,fg='black',font=('times new roman',10,'bold')).grid(row=1,column=6)
T = Text(f2, height=14, width=160,padx=30, pady=30,font=('times new roman',11,'bold'))
T.pack()

# S = Scrollbar(f2)
# T = Text(f2, height=16, width=170,padx=30, pady=30,font=('times new roman',11,'bold'))
# S.pack(side=RIGHT)
# T.pack(side=LEFT)
# S.config(command=T.yview)
# T.config(yscrollcommand=S.set)

labelframe = LabelFrame(f2, text="OUTPUT",padx=20, pady=20,font=('times new roman',11,'bold'))
labelframe.pack(fill=X)

Find41=Label(labelframe,font=('times new roman',10,'bold'),text="SPORTS",bd=16,anchor='nw')
Find41.grid(row=2,column=0)
Find4=Label(labelframe,font=('times new roman',10,'bold'),text="",bd=16,anchor='nw')
Find4.grid(row=3,column=0)
Find4_sp1=Label(labelframe,font=('times new roman',10,'bold'),text="",bd=16,anchor='nw')
Find4_sp1.grid(row=4,column=0)
Find51=Label(labelframe,font=('times new roman',10,'bold'),text="ENTERTAINMENT",bd=16,anchor='nw')
Find51.grid(row=2,column=1)
Find5=Label(labelframe,font=('times new roman',10,'bold'),text="",bd=16,anchor='nw')
Find5.grid(row=3,column=1)
Find5_e1=Label(labelframe,font=('times new roman',10,'bold'),text="",bd=16,anchor='nw')
Find5_e1.grid(row=4,column=1)
Find61=Label(labelframe,font=('times new roman',10,'bold'),text="BUSINESS",bd=16,anchor='nw')
Find61.grid(row=2,column=2)
Find6=Label(labelframe,font=('times new roman',10,'bold'),text="",bd=16,anchor='nw')
Find6.grid(row=3,column=2)
Find6_b1=Label(labelframe,font=('times new roman',10,'bold'),text="",bd=16,anchor='nw')
Find6_b1.grid(row=4,column=2)
Find71=Label(labelframe,font=('times new roman',10,'bold'),text="TECHNOLOGY",bd=16,anchor='nw')
Find71.grid(row=2,column=3)
Find7=Label(labelframe,font=('times new roman',10,'bold'),text="",bd=16,anchor='nw')
Find7.grid(row=3,column=3)
Find7_t1=Label(labelframe,font=('times new roman',10,'bold'),text="",bd=16,anchor='nw')
Find7_t1.grid(row=4,column=3)
Find81=Label(labelframe,font=('times new roman',10,'bold'),text="POLITICS",bd=16,anchor='nw')
Find81.grid(row=2,column=4)
Find8=Label(labelframe,font=('times new roman',10,'bold'),text="",bd=16,anchor='nw')
Find8.grid(row=3,column=4)
Find8_p1=Label(labelframe,font=('times new roman',10,'bold'),text="",bd=16,anchor='nw')
Find8_p1.grid(row=4,column=4)

Riaydh=Label(f3,font=('times new roman',10,'bold'),text="RIAYDH & SHATHI",bd=16,anchor='nw')
Riaydh.grid(row=4,column=4)
#Button(text='File Open', command=callback).pack(fill=x)
mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\riaydh\Anaconda3\lib\tkinter\__init__.py", line 1550, in __call__
#     return self.func(*args)
#   File "<ipython-input-1-cd8a09a634b4>", line 321, in callback
#     lvl2Text.set("")
# NameError: name 'lvl2Text' is not defined
# 0.023354649965388344 0.08399366960090418 0.021297061623698713 0.03033889323568603 0.02142010872630742
# 0.005255873566142997 0.010403993033715399 0.007421304050397622 0.004997278198426837 0.004592085661461754
