# %%
import re
import nltk
from nltk.tokenize import word_tokenize,sent_tokenize
from nltk.corpus import stopwords
from nltk.stem.lancaster import LancasterStemmer
from nltk.stem import PorterStemmer
from collections import Counter
from collections import defaultdict
import os
import os.path

st=PorterStemmer()
path = 'C:\\Users\\ret\\technology_1' 
files = os.listdir(path)
os.chdir(path)
files_txt = [i for i in files if i.endswith('.txt')]
a=[]
#print (len(files_txt))
for x in range(0,len(files_txt)):
        MyFile=open(files_txt[x],'r')
        for y in MyFile.read().split():
            a+=[y]

read_data=filter(str.isalnum,a) 
stop_words=set(stopwords.words("english"))
#filtered_sentence=[]word_list
filtered_sentence=[w for w in read_data if not w in stop_words]

save_path = 'C:\\Users\\ret'
name_of_file = 'technology_corpus_1'
completeName = os.path.join(save_path, name_of_file+".txt")         
fh1 = open(completeName, "w")
#fh1=open("file_corpus_sports.txt","w")
#a=[]
filtered_sentence=[item.lower() for item in filtered_sentence]
filtered_sentence=[x for x in filtered_sentence if not x.isdigit()]
    
    
for words in filtered_sentence:
    if ( len(words)==1 ) :
        filtered_sentence.remove(words)
for x in filtered_sentence:
    if ( len(x)==2 ) :
        filtered_sentence.remove(x)
        
filtered_sentence=[st.stem(f) for f in filtered_sentence]       
for w in  filtered_sentence:
    fh1.write(w+' ')
print((filtered_sentence) )
# Out:
# ['ink', 'help', 'drive', 'democraci', 'asia', 'the', 'kyrgyz', 'mountain', 'state', 'former', 'soviet', 'use', 'invis', 'ink', 'ultraviolet', 'reader', 'elect', 'part', 'drive', 'prevent', 'multipl', 'thi', 'new', 'technolog', 'caus', 'worri', 'guard', 'optim', 'among', 'differ', 'sector', 'effort', 'live', 'reput', '1990', 'island', 'kyrgyz', 'askar', 'push', 'law', 'requir', 'use', 'ink', 'upcom', 'parliamentari', 'presidenti', 'the', 'govern', 'agre', 'fund', 'expens', 'associ', 'the', 'kyrgyz', 'republ', 'seen', 'mani', 'expert', 'backslid', 'high', 'point', 'reach', 'hastili', 'push', 'referendum', 'reduc', 'legisl', 'branch', 'one', 'chamber', 'the', 'use', 'ink', 'one', 'part', 'gener', 'effort', 'show', 'commit', 'toward', 'open', 'elect', 'german', 'soro', 'foundat', 'kyrgyz', 'govern', 'contribut', 'purchas', 'transpar', 'ballot', 'the', 'actual', 'technolog', 'behind', 'ink', 'the', 'ink', 'spray', 'left', 'dri', 'visibl', 'normal', 'presenc', 'ultraviolet', 'light', 'kind', 'use', 'verifi', 'caus', 'ink', 'glow', 'neon', 'yellow', 'entranc', 'poll', 'one', 'elect', 'offici', 'scan', 'finger', 'lamp', 'allow', 'everi', 'voter', 'left', 'thumb', 'spray', 'ink', 'receiv', 'ink', 'show', 'light', 'voter', 'allow', 'enter', 'poll', 'voter', 'refus', 'ink', 'receiv', 'these', 'elect', 'assum', 'even', 'greater', 'signific', 'two', 'larg', 'factor', 'upcom', 'parliamentari', 'elect', 'prelud', 'potenti', 'regim', 'chang', 'presidenti', 'elect', 'autumn', 'well', 'echo', 'recent', 'elect', 'former', 'soviet', 'notabl', 'ukrain', 'the', 'use', 'ink', 'controversi', 'especi', 'among', 'group', 'perceiv', 'wide', 'circul', 'articl', 'compar', 'use', 'ink', 'rural', 'practic', 'mark', 'sheep', 'still', 'common', 'metaphor', 'primarili', 'agricultur', 'the', 'author', 'one', 'articl', 'began', 'petit', 'drive', 'use', 'the', 'greatest', 'part', 'opposit', 'ink', 'often', 'sheer', 'local', 'newspap', 'carri', 'stori', 'ink', 'radioact', 'even', 'ultraviolet', 'reader', 'may', 'caus', 'health', 'aggress', 'middl', 'coalit', 'laud', 'move', 'import', 'step', 'thi', 'type', 'ink', 'use', 'mani', 'elect', 'countri', 'vari', 'south', 'indonesia', 'the', 'common', 'type', 'ink', 'elect', 'indel', 'visibl', 'ink', 'elect', 'afghanistan', 'improp', 'use', 'type', 'ink', 'caus', 'addit', 'the', 'use', 'ink', 'without', 'numer', 'rumor', 'spread', 'christian', 'islam', 'leader', 'assur', 'popul', 'use', 'contrari', 'other', 'rumour', 'associ', 'remov', 'ink', 'variou', 'soft', 'solvent', 'clean', 'product', 'put', 'ink', 'effect', 'get', 'cuticl', 'thumb', 'difficult', 'wash', 'the', 'ink', 'stay', 'finger', 'least', 'hour', 'the', 'use', 'ink', 'reader', 'panacea', 'elect', 'the', 'passag', 'ink', 'law', 'clear', 'step', 'forward', 'toward', 'free', 'fair', 'the', 'wide', 'watch', 'parliamentari', 'elect', 'schedul', 'david', 'mikosz', 'work', 'organis', 'support', 'build', 'democrat', 'china', 'net', 'cafe', 'cultur', 'crackdown', 'chines', 'author', 'close', 'net', 'cafe', 'close', 'month', 'govern', 'accord', 'offici', 'news', 'agenc', 'net', 'cafe', 'close', 'oper', 'chines', 'net', 'cafe', 'oper', 'set', 'strict', 'guidelin', 'mani', 'recent', 'close', 'broke', 'rule', 'limit', 'close', 'the', 'move', 'latest', 'seri', 'step', 'chines', 'govern', 'taken', 'crack', 'consid', 'immor', 'net', 'the', 'offici', 'xinhua', 'news', 'agenc', 'said', 'crackdown', 'carri', 'creat', 'environ', 'young', 'peopl', 'rule', 'introduc', 'demand', 'net', 'cafe', 'least', 'metr', 'away', 'middl', 'elementari', 'the', 'hour', 'children', 'use', 'net', 'cafe', 'also', 'tightli', 'china', 'long', 'worri', 'net', 'cafe', 'unhealthi', 'influenc', 'young', 'the', 'cafe', 'shut', 'three', 'month', 'octob', 'china', 'also', 'tri', 'dictat', 'type', 'comput', 'game', 'peopl', 'play', 'limit', 'amount', 'violenc', 'peopl', 'expos', 'net', 'cafe', 'huge', 'popular', 'china', 'rel', 'high', 'cost', 'comput', 'hardwar', 'mean', 'peopl', 'pc', 'thi', 'first', 'time' ...

# %%
import re
import nltk
from nltk.tokenize import word_tokenize,sent_tokenize
from nltk.corpus import stopwords
from nltk.stem.lancaster import LancasterStemmer
from nltk.stem import PorterStemmer
from collections import Counter
from collections import defaultdict
import os
import os.path

st=PorterStemmer()
path = 'C:\\Users\\ret\\technology_2' 
files = os.listdir(path)
os.chdir(path)
files_txt = [i for i in files if i.endswith('.txt')]
a=[]
#print (len(files_txt))
for x in range(0,len(files_txt)):
        MyFile=open(files_txt[x],'r')
        for y in MyFile.read().split():
            a+=[y]

read_data=filter(str.isalnum,a) 
stop_words=set(stopwords.words("english"))
#filtered_sentence=[]word_list
filtered_sentence=[w for w in read_data if not w in stop_words]

save_path = 'C:\\Users\\ret'
name_of_file = 'technology_corpus_2'
completeName = os.path.join(save_path, name_of_file+".txt")         
fh1 = open(completeName, "w")
#fh1=open("file_corpus_sports.txt","w")
#a=[]
    
filtered_sentence=[item.lower() for item in filtered_sentence]
filtered_sentence=[x for x in filtered_sentence if not x.isdigit()]
    
    
for words in filtered_sentence:
    if ( len(words)==1 ) :
        filtered_sentence.remove(words)
for x in filtered_sentence:
    if ( len(x)==2 ) :
        filtered_sentence.remove(x)
        
filtered_sentence=[st.stem(f) for f in filtered_sentence]       
for w in  filtered_sentence:
    fh1.write(w+ ' ')
print((filtered_sentence) )
# Out:
# ['sun', 'offer', 'process', 'hour', 'sun', 'microsystem', 'launch', 'servic', 'allow', 'custom', 'requir', 'huge', 'comput', 'power', 'rent', 'sun', 'grid', 'cost', 'user', 'worth', 'process', 'storag', 'power', 'system', 'maintain', 'grid', 'comput', 'latest', 'buzz', 'phrase', 'compani', 'believ', 'comput', 'capac', 'import', 'commod', 'hardwar', 'sun', 'liken', 'grid', 'comput', 'develop', 'the', 'system', 'could', 'matur', 'way', 'util', 'electr', 'water', 'said', 'chief', 'oper', 'offic', 'jonathan', 'build', 'grid', 'use', 'buck', 'ask', 'webcast', 'launch', 'quarterli', 'network', 'comput', 'event', 'the', 'compani', 'persuad', 'data', 'centr', 'manag', 'adopt', 'new', 'model', 'said', 'alreadi', 'interest', 'custom', 'ga', 'financi', 'servic', 'some', 'want', 'book', 'comput', 'capac', 'processor', 'sun', 'schwartz', 'ran', 'demonstr', 'show', 'data', 'could', 'process', 'protein', 'fold', 'hundr', 'server', 'use', 'work', 'problem', 'second', 'although', 'took', 'experi', 'cost', 'use', 'worth', 'comput', 'the', 'sun', 'grid', 'reli', 'oper', 'system', 'own', 'initi', 'hous', 'grid', 'exist', 'premis', 'use', 'idl', 'server', 'test', 'softwar', 'ship', 'said', 'much', 'system', 'cost', 'develop', 'alreadi', 'rival', 'argu', 'capac', 'servic', 'cheaper', 'offer', 'laser', 'help', 'bridg', 'network', 'gap', 'indian', 'telecommun', 'firm', 'turn', 'laser', 'help', 'overcom', 'problem', 'set', 'voic', 'data', 'network', 'tata', 'teleservic', 'use', 'laser', 'make', 'link', 'offic', 'core', 'the', 'laser', 'bridg', 'work', 'across', 'distanc', '4km', 'set', 'much', 'faster', 'cabl', 'month', 'laser', 'help', 'firm', 'set', 'network', 'particular', 'geographi', 'get', 'permiss', 'dig', 'ground', 'lay', 'pipe', 'bit', 'said', 'vice', 'presid', 'network', 'traffic', 'layout', 'ground', 'mean', 'dig', 'uniqu', 'permiss', 'dig', 'road', 'lay', 'cabl', 'imposs', 'said', 'far', 'easier', 'secur', 'permiss', 'put', 'network', 'hardwar', 'thi', 'led', 'tata', 'turn', 'equip', 'use', 'laser', 'make', 'final', 'mile', 'leap', 'core', 'network', 'premis', 'the', 'lightpoint', 'laser', 'bridg', 'work', 'distanc', '4km', 'use', 'rout', 'voic', 'data', 'busi', 'backbon', 'the', 'hardwar', 'work', 'pair', 'beam', 'data', 'air', 'form', 'laser', 'the', 'laser', 'bridg', 'rout', 'data', 'speed', 'time', 'faster', '512kbp', 'broadband', 'tata', 'run', 'hardwar', 'modest', 'speed', 'the', 'laser', 'also', 'ideal', 'india', 'particularli', 'suitabl', 'rain', 'rate', 'littl', 'low', 'hardli', 'ever', 'place', 'rain', 'heavi', 'fog', 'common', 'laser', 'link', 'struggl', 'maintain', 'good', 'connect', 'the', 'laser', 'link', 'also', 'take', 'far', 'less', 'time', 'set', 'get', 'said', 'get', 'normal', 'time', 'period', 'set', 'dig', 'road', 'lay', 'cabl', 'take', 'week', 'thi', 'speed', 'set', 'help', 'tata', 'aggress', 'expans', 'just', 'month', 'ago', 'firm', 'custom', 'town', 'but', 'end', 'march', 'firm', 'hope', 'reach', 'import', 'pace', 'said', 'game', 'firm', 'hold', 'audit', 'video', 'game', 'firm', 'biowar', 'hold', 'open', 'audit', 'peopl', 'becom', 'cast', 'member', 'futur', 'the', 'make', 'role', 'play', 'game', 'knight', 'old', 'republ', 'neverwint', 'seek', 'peopl', 'age', 'the', 'compani', 'say', 'look', 'wide', 'varieti', 'peopl', 'use', 'face', 'model', 'everyon', 'chosen', 'appear', 'video', 'game', 'receiv', 'fee', 'use', 'the', 'compani', 'invit', 'peopl', 'come', 'along', 'shop', 'mall', 'west', 'friday', 'bring', 'along', 'piec', 'photo', 'hundr', 'hundr', 'charact', 'typic', 'biowar', 'said', 'shauna', 'audio', 'extern', 'resourc', 'peopl', 'live', 'citi', 'villag', 'need', 'ordinari', 'peopl', 'interest', 'she', 'everyon', 'model', 'world', 'want', 'model', 'peopl', 'chosen', 'appear', 'game', 'head', 'scan', 'three', 'hundr', 'photo', 'head', 'taken', 'model', 'head', 'gener', 'model', 'look', 'exactli', 'like', 'person', 'realli', 'quit', 'incred', 'detail', 'said', 'she', 'said', 'chosen', 'particip', 'control', 'imag ...
